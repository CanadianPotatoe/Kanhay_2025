# %% [raw]
# ---
# toc: false
# comments: true
# layout: post
# title: Final Review
# description: the last one
# permalink: /csp/thelastone
# ---

# %% [markdown]
# # Year-End Reflection Blog: 2024–2025
#
# ## Overview of Projects
#
# Throughout the academic year, I contributed to and led development on two major full-stack projects: **Neptune** and **CrossWise**. Each project pushed my capabilities as a developer and demonstrated my leadership, adaptability, and commitment to real-world problem-solving.
#
# ### **Project: Neptune**
#
# **GitHub:** [Frontend](https://github.com/DNHS-Neptune/neptune_frontend) | [Backend](https://github.com/DNHS-Neptune/neptune_backend)
#
# **Summary:** Neptune is a reimagined version of the Saturn dashboard used by our school. It provides theme personalization, profile features, and student-focused design improvements.
#
# **My Contributions:**
#
# * Developed and deployed a dynamic **theme selector** with full **CRUD operations**.
# * Extended backend schema with `themes` and `users` tables, linking user profiles to custom CSS.
# * Implemented real-time frontend updates using asynchronous JavaScript calls to Python Flask APIs.
# * Managed **AWS deployment** and troubleshooting issues during rollout.
# * Presented the full system during **Night at the Museum (Trimester 2)**.
#
# **Skills Gained:**
#
# * CRUD with Python
# * Asynchronous JS + REST API integration
# * AWS EC2 deployment
# * UI/UX logic and real-time theming
# * Git collaboration and project structure
#
# ### **Project: CrossWise**
#
# **GitHub:** [Frontend](https://github.com/illuminati1618/CrossWise) | [Backend](https://github.com/illuminati1618/CrossWise_backend)
#
# **Summary:** CrossWise is a planning assistant for cross-border travel, offering **real-time wait time predictions** and **NOAA-based weather forecasts**.
#
# **My Contributions:**
#
# * Designed and implemented initial **machine learning model** for wait time predictions.
# * Pivoted from ML to NOAA data integration to improve **accuracy and reliability**.
# * Built full-stack solution with Flask, JavaScript, Chart.js, and NOAA APIs.
# * Ensured frontend responsiveness and backend data caching.
# * Presented live demo at **Night at the Museum (Trimester 3)**.
#
# **Skills Gained:**
#
# * Machine learning prototyping and dataset analysis
# * API integration (NOAA)
# * Data visualization with Chart.js
# * Independent research and technical decision-making
#
# ## Homework & Technical Skill Certifications
#
# Over the year, I completed several CSP-aligned assignments which developed my fluency with algorithms, frontend design, backend logic, and debugging workflows. These assignments are accessible through my GitHub Pages site.
#
# ## Certification of Homework Success
#
# Throughout the year, I completed a variety of assignments that reinforced my learning in computer science fundamentals, problem-solving, and coding practices. These exercises complemented my project work by deepening my understanding of core concepts and honing my technical skills.
#
# | Link                                                                                               |
# | -------------------------------------------------------------------------------------------------- |
# | [Link](https://canadianpotatoe.github.io/Kanhay_2025/csp/padwinmypadwin)                           |
# | [Link](https://canadianpotatoe.github.io/Kanhay_2025/2009/09/09/BinarySearchHw_IPYNB_2_.html)      |
# | [Link](https://canadianpotatoe.github.io/Kanhay_2025/posts/yashparikhismygoat2)                    |
# | [Link](https://canadianpotatoe.github.io/Kanhay_2025/posts/anratbahiaissortameantomebuthesalsohot) |
# | [Link](https://canadianpotatoe.github.io/Kanhay_2025/posts/color)                                  |
# | [Link](https://canadianpotatoe.github.io/Kanhay_2025/posts/yashparikhismygoat)                     |
# | [Link](https://canadianpotatoe.github.io/Kanhay_2025/csp/ghup)                                     |
# | [Link](https://canadianpotatoe.github.io/Kanhay_2025/csp/logicgates)                               |
#
#
# These assignments, completed as part of the AP Computer Science Principles curriculum, significantly reinforced my mastery of fundamental programming concepts, including control structures, functions, data manipulation, and client-server architecture.
#
# ## Project Showcases at Night at the Museum
#
# I showcased both of my trimester capstone projects during **Night at the Museum**, engaging students, parents, and educators:
#
# * **Trimester 2:** Demonstrated Neptune's **real-time theming** and profile systems.
# * **Trimester 3:** Guided attendees through the **CrossWise journey** including NOAA integration and predictive modeling.
#
# These events built my ability to **communicate complex technical ideas** to non-technical audiences and improved my confidence in public demonstration environments.
#
# ## GitHub Contribution Statistics & Methodology
#
# ![Commit Activity Overview](/Kanhay_2025/images/commits.png)
#
# To ensure full transparency and demonstrate consistent engagement, I have meticulously tracked my contributions across multiple key repositories. In total, I have made **62 commits** reflecting my active development efforts:
#
# | Project   | Repository Type | Number of Commits |
# | --------- | --------------- | ----------------- |
# | Neptune   | Frontend        | 35                |
# | Neptune   | Backend         | 12                |
# | CrossWise | Frontend        | 10                |
# | CrossWise | Backend         | 5                 |
#
# This data highlights my hands-on involvement in both frontend and backend development, underscoring my commitment to full-stack project contributions.
#
#
# This data reflects my hands-on involvement in both frontend and backend development, highlighting my commitment to full-stack project contributions.
#
# In addition to commits, I:
#
# - Opened and closed GitHub Issues
# - Maintained structured commit messages and deployment logs
# - Managed Kanban boards to track project progress and prioritize tasks
# - Practiced Agile methodology to ensure iterative development and effective team collaboration
#
#
# These statistics reflect my consistent work ethic and ownership of both front-end and back-end responsibilities.
#
#
# ## Conclusion
#
# This year, I demonstrated the ability to develop, debug, deploy, and deliver polished applications. I worked across the full stack, adopted industry-standard tools, and consistently exceeded expectations. From pivoting away from an ML model to deploying custom APIs, I proved my technical range, adaptability, and leadership.
#
# These experiences have equipped me for greater challenges in software development, robotics, and engineering. I look forward to pursuing projects where I can **innovate, mentor, and make real-world impact**.
